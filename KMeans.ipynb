# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
iris=load_iris()
X=iris.data

# %%
kmeans = KMeans(n_clusters=5,random_state=0)
kmeans.fit(X)
# Out:
# C:\Users\Sukirtha\AppData\Roaming\Python\Python312\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5, random_state=0)

# %%
centers=kmeans.cluster_centers_
labels=kmeans.labels_

# %%
plt.figure(figsize=(10,8))

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', alpha=0.7)
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='+', label='Cluster Centers')
plt.title('KMeans Clustering of Iris Dataset')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.legend()
plt.grid(True)
plt.show()
